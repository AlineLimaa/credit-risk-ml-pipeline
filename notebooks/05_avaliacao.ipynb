# %% [markdown]
# # Interpretabilidade e Insights de Negócio
#
# ## Objetivo
# Modelos de risco de crédito precisam ser interpretáveis para atender exigências regulatórias e apoiar decisões estratégicas.
#
# Neste notebook, analisamos:
# - Importância das variáveis
# - Impacto das features no risco de crédito
# - Insights acionáveis para o negócio
#
# O objetivo é transformar resultados técnicos em informações compreensíveis para stakeholders.
